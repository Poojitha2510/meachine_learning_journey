# %%
#type casting
a="10"

y=int(a)
print(y)
print(type(y))
# Out:
# 10
# <class 'int'>

# %%
#assignmen add price and gst percentage
product_price=120
gst=18#
print(((gst/100)*product_price)+product_price)
# Out:
# 141.6

# %%
#assignment 2 how to calculate percentage
total=100
score=200
print(((score*100)/total))
# Out:
# 40.0

# %%
#assignment3 to find how many boxex are field and remaining choclates t=total chocolates b=boxes
t=57
b=8
print(t//b) #floor division
print(t%b) #modulo operator
# Out:
# 7
# 1

# %%
o=2850
dc=120
p=5.2
total=((((o*p)/100)+(o+dc))/5)
print(total)
# Out:
# 623.64
