# %%
#functions
#Function declaration
def make_tea():
    print("Boil water")
    print("Put tea and ginger")
    print("put sugar")
    print("pour tea in cup")
#Function call
make_tea()
# Out:
# Boil water
# Put tea and ginger
# put sugar
# pour tea in cup

# %%
#how function works
print("this is the first line")
def make_tea():
    print("print statement after func declaration")
    print("Boil water")
    print("Put tea and ginger")
    print("put sugar")
    print("pour tea in cup")
    print("print statement at last in func declaration")
print("print statement after ending(outside the) of function declaration")
make_tea()
print("print statement after func calling")
# Out:
# this is the first line
# print statement after ending(outside the) of function declaration
# print statement after func declaration
# Boil water
# Put tea and ginger
# put sugar
# pour tea in cup
# print statement at last in func declaration
# print statement after func calling

# %%
#explain the concept of parameters and arguments
def make_tea(sugar):#giving the how much sugsr to use for making the tea
    print("Boil water")
    print("Put tea and ginger")
    print(sugar,"cups of sugar added")

#to take input from the user that how much sugar can use
sugar=int(input("enter how much sugar you want"))
make_tea(sugar)# indicates or passing the information that use 1 cup of sugar to make tea

#make_tea(4)# indicates or passing the information that use 1 cup of sugar to make tea
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 8
#       5     print(sugar,"cups of sugar added")
#       7 #to take input from the user that how much sugar can use
# ----> 8 sugar=int(input("enter how much sugar you want"))
#      10 make_tea(sugar)# indicates or passing the information that use 1 cup of sugar to make tea
#      12 #make_tea(4)# indicates or passing the information that use 1 cup of sugar to make tea
#
# ValueError: invalid literal for int() with base 10: ''

# %%
#return fuction is  used to return  the value   
def add(a,b):
    #print(a+b)#just printing on screen without informing to us
    #returns means you return value to me then i will print in this situations we use the return statement
    c=a+b
    return c #who are calling go there withtaking c value 

d=add(2,3)
print(d)#does not print anything if don't you write return statement
# Out:
# 5

# %%
#scoping
def add(a,b):
    c=a+b    # c (local scope) variable can acess only inside the function (scope of c variable is only inside the function)
    return c 
c=add(2,3)#here is c act as new variable(global scope)
print(c)
# Out:
# 5

# %%
#design a small game
#problem statement first we decide a number then ask user to guess the number if the guess number is less than number then habe to increase and if greater then decrese
number=57
def play_single_game():

    guess=input("enter the guess number")

    if guess==number:
        print("guess is correct")
    elif guess<number:
        print("you have guessed the small number")
    else:
        print("you have guessed the big number")
while True:
    play_single_game()

    playAagain=input("do you want to play again")
    if playAagain=="No":
        break

# %%
#another way
number=57
def play_single_game():

    guess=input("enter the guess number")

    if guess==number:
        print("guess is correct")
        return 1
    elif guess<number:
        print("you have guessed the small number")
        return 0
    else:
        print("you have guessed the big number")
        return 0
while True:
    guessed_it=play_single_game()

    if guessed_it==1:
        break
